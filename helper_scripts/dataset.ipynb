# %% [markdown]
# # Datasets
#
# CICIoT2023 - `wget -r -np -A '*.csv' http://cicresearch.ca/IOTDataset/CIC_IOT_Dataset2023/Dataset/CSV/`
#
# CICIoT2024 - `wget -r -np -A '*.csv' http://cicresearch.ca/IOTDataset/CIC%20IoT-IDAD%20Dataset%202024/Dataset/`

# %% [markdown]
# ***
#
# ## CICIoT2023

# %% [markdown]
# ***
#
# ## CICIoT2024

# %%
# matplotlib inline

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import tree

# %%
path = "CIC IoT-IDAD 2024 Dataset/Device Identification_Anomaly Detection - Packet Based Features/BenignTraffic/BenignTraffic.csv"

df = pd.read_csv(path)

df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297063 entries, 0 to 297062
# Data columns (total 135 columns):
#  #    Column                                 Dtype
# ---   ------                                 -----
#  0    stream                                 int64
#  1    src_mac                                object
#  2    dst_mac                                object
#  3    src_ip                                 object
#  4    dst_ip                                 object
#  5    src_port                               int64
#  6    dst_port                               int64
#  7    inter_arrival_time                     float64
#  8    time_since_previously_displayed_frame  float64
#  9    port_class_dst                         int64
#  10   l4_tcp                                 int64
#  11   l4_udp                                 int64
#  12   ttl                                    int64
#  13   eth_size                               int64
# ...

# %%
path = "CIC IoT-IDAD 2024 Dataset/Anomaly Detection - Flow Based features/Benign/BenignTraffic.pcap_Flow.csv"

df = pd.read_csv(path)

df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183630 entries, 0 to 183629
# Data columns (total 84 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Flow ID                     183630 non-null  object
#  1   Src IP                      183630 non-null  object
#  2   Src Port                    183630 non-null  int64
#  3   Dst IP                      183630 non-null  object
#  4   Dst Port                    183630 non-null  int64
#  5   Protocol                    183630 non-null  int64
#  6   Timestamp                   183630 non-null  object
#  7   Flow Duration               183630 non-null  int64
#  8   Total Fwd Packet            183630 non-null  int64
#  9   Total Bwd packets           183630 non-null  int64
#  10  Total Length of Fwd Packet  183630 non-null  float64
#  11  Total Length of Bwd Packet  183630 non-null  float64
#  12  Fwd Packet Length Max       183630 non-null  float64
# ...
